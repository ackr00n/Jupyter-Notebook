# %% [markdown]
# # WEB SCRAPPING

# %% [markdown]
# Analizar una web
# libreria request

# %%
import requests
from bs4 import BeautifulSoup

web = 'https://valeriemoreau.com/'

pagina = requests.get(web)
#print (pagina.content)
soup = BeautifulSoup(pagina.content,"html.parser")

#print (soup)

resultado = soup.find(id = "st-container")
print (resultado)
# Out:
# <div class="st-container" id="st-container">
# <div class="st-content">
# <div class="sticky_header transparency_light" id="page_wrapper">
# <div class="top-headers-wrapper">
# <div id="site-top-bar">
# <div class="row">
# <div class="large-12 columns">
# <div class="site-top-bar-inner" style="max-width:1680px">
# <div class="site-top-message">
# </div>
# <div class="site-top-bar-social-icons-wrapper">
# <ul class="sk_social_icons_list right">
# <li class="sk_social_icon default_icon">
# <a class="sk_social_icon_link" href="https://www.facebook.com/valerie.moreau.fashion" target="_blank">
# <svg class="" height="24" viewbox="0 0 50 50" width="24" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
# ...

# %%
import requests
from bs4 import BeautifulSoup

web = 'https://www.infojobs.net/'
    
pagina = requests.get(web)


soup = BeautifulSoup(pagina.content,"html.parser")

result = soup.find_all("div", class_="criteo-tags-div")
print (result)
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup


web = 'https://www.xataka.com/categoria/seguridad'
pagina_request = requests.get(web)

soup = BeautifulSoup(pagina_request.content,"html.parser")
resultado = soup.find(id = "iat-adhesion-bar-729379")
clase = soup.find_all("div", class_ = "customize-me")

print(resultado)
print(clase)
# Out:
# None
# [<div class="customize-me">
# <div class="head-content-favs">
# <div class="head-container head-container-with-ad head-container-with-corner m-favicons-compact m-head-masthead">
# <div class="head head-with-ad is-init">
# <div class="head-favicons-container">
# <nav class="head-favicons">
# <div class="head-favicons-index head-webedia-logo">
# <a data-target="#head-favicons" href="https://www.webedia.es/" id="favicons-toggle"><abbr title="Webedia">Webedia</abbr></a>
# </div>
# </nav>
# </div>
# <div class="masthead-site-lead">
# <div class="masthead-container">
# <div class="masthead-logo">
# <div class="masthead-logo-brand">
# <a class="masthead-brand" href="/">Xataka</a>
# </div>
# </div>
# <nav class="masthead-actions">
# <ul class="masthead-actions-list">
# <li class="masthead-actions-list-item"><a class="masthead-actions-menu m-v1 js-toggle" data-searchbox="#search-field-1" href="#sections">Menú</a></li>
# ...

# %%
try:



    web = input("Escriba el URL de la web: ")
    
except:
    print("URL incorrecta")
